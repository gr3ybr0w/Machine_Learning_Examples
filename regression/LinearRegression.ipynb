# %% [markdown]
# <a href="https://colab.research.google.com/github/gr3ybr0w/Machine_Learning_Examples/blob/master/regression/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
import altair as alt
import numpy as np
import pandas as pd
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

data = pd.DataFrame({'pageSpeeds':pageSpeeds, 'purchaseAmount':purchaseAmount})

# %%
scatter_chart = alt.Chart(data).mark_point().encode(x='pageSpeeds:Q',y='purchaseAmount:Q')

scatter_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# 0.9904609166432558

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

pred_data = pd.DataFrame({'pageSpeeds':pageSpeeds, 'fitLine':fitLine})

line_chart = alt.Chart(pred_data).mark_line(color='red').encode(x='pageSpeeds:Q', y='fitLine:Q')

scatter_chart + line_chart
# Out:
# alt.LayerChart(...)
